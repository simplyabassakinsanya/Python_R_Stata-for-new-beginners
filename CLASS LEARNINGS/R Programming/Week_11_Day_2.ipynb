# %%
a <- 20*3
a
# Out:
# [1] 60

# %%
age <- 20
if (age >= 20) {
  print("My Guy")
}
# Out:
# [1] "My Guy"

# %%
Grade <- 89
if (Grade > 90) {
  print("You too much")
} else {
  print("You can still do better")
}
# Out:
# [1] "You can still do better"

# %%
Age <- 45
if (Age > 50) {
  print("Agbaya")
} else if (Age >= 46) {
  print("You don dey old")
} else {
  print("You are getting closer")
}
# Out:
# [1] "You are getting closer"

# %%
Age <- 40
if (Age > 40) {
  print("Okay")
  if (Age > 50) {
  print("Agbaya")
  } else if (Age > 41) {
  print("Not_bad")
  }
} else {
  print("Correct")
}
# Out:
# [1] "Correct"
