# %% [markdown]
# Practical R Plotting
#
# R has two major plotting systems:
#
# - Base R graphics: Quick & Simple
#
# - ggplot2 (Grammar of Graphics): Professional & Flexible

# %%
# SAMPLE DATASET FOR PRACTICAL

# create a sample dataset
data <- data.frame(
  Name = c("A", "B", "C", "D", "E"),
  Sales = c(200, 450, 300, 500, 400),
  Profit = c(50, 120, 80, 150, 100),
  Region = c("North", "South", "East", "West", "North")
)

# Printing out the result of the data created.
data
# Out:
#   Name Sales Profit Region
# 1 A    200    50    North
# 2 B    450   120    South
# 3 C    300    80    East
# 4 D    500   150    West
# 5 E    400   100    North

# %% [markdown]
# Basic Plots in Base R
#
# - Scatter (Relationship between variables).
#
# Use case: Correlation, trend detection.

# %%
plot(data$Sales, data$Profit,
     main = "Sales vs Profit",
     xlab = "Sales",
     ylab = "Profit",
     col = "blue",
     pch = 19)
# Out:
# Plot with title “Sales vs Profit”

# %% [markdown]
# 2. Line Plot (Trend Over Time)
#
# Use Case: Time series analysis.

# %%
plot(data$Sales, , type = "l",
     main = "Sales Trend",
     xlab = "Index",
     ylab = "Sales",
     col = "green",
     lwd = 2)
# Out:
# Plot with title “Sales Trend”

# %% [markdown]
# 3. Bar Chart (Categorical Comparison)
#
# Use Case: Category comparison

# %%
barplot(data$Sales,
        names.arg = data$Name, # names.arg stands for "names of the arguments (bars)" and it controls the label shown on the x-axis (under each bar).
        main = "Sales by Person",
        col = "Orange")
# Out:
# Plot with title “Sales by Person”

# %%
# create a sample dataset
data <- data.frame(
  Name = c("Aaaaaa", "Bbbbbb", "Cccccc", "Dddddd", "Eeeeee"),
  Sales = c(200, 450, 300, 500, 400),
  Profit = c(50, 120, 80, 150, 100),
  Region = c("North", "South", "East", "West", "North")
)

# %%
# Horizontal bar chart: This is usually adopted if the labels are long and in this case, the "Name" is quite long.

barplot(data$Sales,
        names.arg = data$Name,
        main = "Sales by Person",
        col = "Orange",
        horiz = TRUE)
# Out:
# Plot with title “Sales by Person”

# %%
# You can also use the Cex operator in controlling the label size.

barplot(data$Sales,
        names.arg = data$Name,
        main = "Sales by Person",
        col = "Orange",
        cex.names = 0.5,
        horiz = TRUE)
# Out:
# Plot with title “Sales by Person”

# %% [markdown]
# 4. Histogram (Distribution)
#
# Use Case: Frequency distribution. A histogram groups numbers into ranges and shows how many values fall into each range.

# %%
# create a sample dataset
data <- data.frame(
  Name = c("A", "B", "C", "D", "E"),
  Sales = c(200, 450, 300, 500, 400),
  Profit = c(50, 120, 80, 150, 100),
  Region = c("North", "South", "East", "West", "North")
)

# %%
hist(data$Sales,                  # hist() - This function creates a histogram.
     main = "Sales Distribution",
     col = "purple",
     breaks = 5)                  # breaks = 5 => Divide the data into five(5) intervals (bins)
     # Note:- What the graph shows
     # X-axis => ranges of sales
     # Y-axis => frequency (count)
# Out:
# Plot with title “Sales Distribution”

# %%
# Outliers in R Boxplots:

# create a sample dataset
data <- data.frame(
  Name = c("A", "B", "C", "D", "E"),
  Sales = c(200, 450, 300, 500, 900),
  Profit = c(50, 120, 80, 150, 100),
  Region = c("North", "South", "East", "West", "North")
)

boxplot(data$Sales,
        main = "Sales Boxplot",
        col = "cyan")
# Out:
# Plot with title “Sales Boxplot”

# %% [markdown]
# The outlier points outside whiskers.
# # In summary,
# - The box shows where most of the data lie.
# - The line inside is the median.
# - The whiskers show the spread
# - Any dots  outside are outliers.

# %% [markdown]
# 5. Box Plot (Outliers & Spread)
#
# Box Plot is a graphical visualization which summarizes data into a box-and-whisker-plot using the five (5) key statistics displayed in the table below.
#
# Use Case: Detect outliers

# %% [markdown]
# | Component   | Meaning        |
# | ----------- | -------------- |
# | Minimum     | Lowest value   |
# | Q1 (25%)    | Lower quartile |
# | Median (Q2) | Middle value   |
# | Q3 (75%)    | Upper quartile |
# | Maximum     | Highest value  |

# %%
boxplot(data$Sales,
        main = "Sales Boxplot",
        col = "cyan")
# Out:
# Plot with title “Sales Boxplot”

# %% [markdown]
# Note =>
#
# From the result above;
#
# 1. Median (Middle line), which is around 400. The horizontal line inside the box.
#
# 2. The Box (Q1 or 25% & Q3 or 75%)
#
# - Bottom of box => ~ 300 (Q1)
#
# - Top of the box => ~450(Q3)
#
# The box contains 50% of the data.
#
# 3. Whiskers (Line Outside Box)
#
# - Lower whiskers => ~200
#
# - Upper Whiskers => ~500
#
# The Whiskers shows the range of the data.

# %%
# create a sample dataset
data <- data.frame(
  Name = c("A", "B", "C", "D", "E"),
  Sales = c(200, 450, 300, 500, 400),
  Profit = c(50, 120, 80, 150, 100),
  Region = c("North", "South", "East", "West", "North")
)

# %% [markdown]
# Pie Chart (Proportion)
#
# - Use Case: Percentage contribution.

# %%
pie(data$Sales,
    labels = data$Name,
    main = "Sales Share")
# Out:
# Plot with title “Sales Share”
