# %%
Name = "Abass"
Age = 41
Attractive = True

print(Name)
print(Age)
print(Attractive)
# Out:
# Abass
# 41
# True

# %%
Name, Age, Attractive = "Abass", 41, True
print(Name,Age,Attractive)
# Out:
# Abass 41 True

# %%
Abass = 30
Damola = 30
Temilola = 30
Tamilore = 30
print(Abass)
print(Damola)
print(Temilola)
print(Tamilore)
# Out:
# 30
# 30
# 30
# 30

# %%
Abass = Damola = Temilola = Tamilore = 30
print(Abass, Damola, Temilola, Tamilore)
# Out:
# 30 30 30 30
