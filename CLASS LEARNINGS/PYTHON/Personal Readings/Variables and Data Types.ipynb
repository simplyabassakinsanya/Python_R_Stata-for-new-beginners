# %%
# String or Text or Object
print("i love pizza")
# Out:
# i love pizza

# %%
print("Good morning Abass!")
# Out:
# Good morning Abass!

# %%
print('data')
# Out:
# data

# %%
print('mummy temmy')
# Out:
# mummy temmy

# %%
name = "Abass"
print(name)

name = "Abass " +"Soji " +"Akinsanya"
print(name)
# Out:
# Abass
# Abass Soji Akinsanya

# %%
name = "Soji"
print("Hello "+name)
print("Good morning "+name)
print("How are you" +" "+ name)
print("It shall be well with you "+name)
print(type(name))
# Out:
# Hello Soji
# Good morning Soji
# How are you Soji
# It shall be well with you Soji
# <class 'str'>

# %%
first_name = "Abass"
middle_name = "Soji"
last_name = "Akinsanya"
full_name = first_name +" "+ middle_name +" "+ last_name
print("Hello"+" "+full_name)
# Out:
# Hello Abass Soji Akinsanya

# %%
first_name = "Tamilore"
middle_name = "Joel"
last_name = "Akinsanya"
full_name = first_name+" "+middle_name+" "+last_name
print(full_name)
print(first_name)
print("Good night" +" "+ full_name)
# Out:
# Tamilore Joel Akinsanya
# Tamilore
# Good night Tamilore Joel Akinsanya

# %%
#Integer (Int)
Age = 40
print(Age)
print(Age + 1)
Age += 1
print(Age)
print(type(Age))
Ages = 45
print(Ages)
Ages +=1
print(Ages)
print(Ages + 10)
# Out:
# 40
# 41
# 41
# <class 'int'>
# 45
# 46
# 56

# %%
print("Your age is"+" "+str(Ages+10))
print("Your father's age is "+str(Age+10))
# Out:
# Your age is 56
# Your father's age is 51

# %%
# Float
height = 250.5
print(height)

print(type(height))
# Out:
# 250.5
# <class 'float'>

# %%
print("Abass's height is around "+str(height))
print("My height is exactly "+str(height)+"cm")
# Out:
# Abass's height is around 250.5
# My height is exactly 250.5cm

# %%
# Boolean
Ronaldo = True
print(Ronaldo)

print(type(Ronaldo))

print("Is Abass a human being: "+str(Ronaldo))
# Out:
# True
# <class 'bool'>
# Is Abass a human being: True
