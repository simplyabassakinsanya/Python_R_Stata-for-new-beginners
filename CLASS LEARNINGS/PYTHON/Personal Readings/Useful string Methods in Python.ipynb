# %%
name = "abass akinsanya"
print(name)
print(len(name))
print(name.find('s'))
print(name.find('i'))
print(name.capitalize())
print(name.upper())
print(name.lower())
print(name.isdigit())
print(name.isalpha())
print(name.count("s"))
print(name.count("a"))
print(name*2)
# Out:
# abass akinsanya
# 15
# 3
# 8
# Abass akinsanya
# ABASS AKINSANYA
# abass akinsanya
# False
# False
# 3
# 5
# abass akinsanyaabass akinsanya
