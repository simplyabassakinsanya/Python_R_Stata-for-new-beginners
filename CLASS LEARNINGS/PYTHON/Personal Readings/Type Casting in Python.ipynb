# %%
x = 1
y = 2.0
z = "3"

print(x)
print(type(x))

print(y)
print(type(y))

print(z)
print(type(z))
# Out:
# 1
# <class 'int'>
# 2.0
# <class 'float'>
# 3
# <class 'str'>

# %%
y = int(y)
print(y)

z = float(z)
print(z)

x = str(x)
print(x)
# Out:
# 2
# 3.0
# 1

# %%
print(type(y))
print(type(x))
print(type(z))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
x = int(x)
print(x)
print(type(x))
# Out:
# 1
# <class 'int'>

# %%
print(x)
print(type(x))
print(y)
print(type(y))
print(z)
print(type(z))
# Out:
# 1
# <class 'int'>
# 2
# <class 'int'>
# 3.0
# <class 'float'>

# %%
x = float(x)
print(x)
print(int(x))
# Out:
# 1.0
# 1

# %%
print(int(x))
# Out:
# 1

# %%
print(type(x))
# Out:
# <class 'float'>

# %%
print(x + x)
print(type(x))
# Out:
# 2.0
# <class 'float'>

# %%
print("z"+str(z))
# Out:
# z3.0
