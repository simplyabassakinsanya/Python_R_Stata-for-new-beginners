# %%
import pandas as pd

# %%
# Load a CSV file (student scores)
data = pd.read_csv("C:/Users/abass/OneDrive/Desktop/STATISTICAL TOOLS/PYTHON/Create a Folder/Class Assignment.csv")

# %%
# Explore the data 
print(data.head()) # First 5 rows
# Out:
#         Name  Math  English  Science
# 0        Ore    55       90       42
# 1    Ayomide    60       70       76
# 2     Kiishi    90       88       78
# 3  Happiness    92       95       89
# 4   Victoria    90       89       90

# %%
print(data.describe()) # Summary statistics
# Out:
#             Math    English    Science
# count   5.000000   5.000000   5.000000
# mean   77.400000  86.400000  75.000000
# std    18.270194   9.555103  19.493589
# min    55.000000  70.000000  42.000000
# 25%    60.000000  88.000000  76.000000
# 50%    90.000000  89.000000  78.000000
# 75%    90.000000  90.000000  89.000000
# max    92.000000  95.000000  90.000000

# %%
print(data["Math"].mean()) # Average math score
# Out:
# 77.4

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Simple plot
scores = [55, 60, 90, 92]
plt.plot(scores)
plt.title("Student Scores")
plt.show()

# Seaborn for nicer visuals
sns.histplot(data["Math"], bins=5, kde=True)
plt.title("Distribution of Math Scores")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Line plot of scores 
plt.plot(data["Name"], data["Math"], label="Math")
plt.plot(data["Name"], data["English"], label="English")
plt.plot(data["Name"], data["Science"], label="Science")
plt.legend()
plt.title("Student Scores by Subject")
plt.show()

# Histogram of Math scores
sns.histplot(data["Math"], bins=5, kde=True)
plt.title("Distribution of Math Scores")
plt.show()
