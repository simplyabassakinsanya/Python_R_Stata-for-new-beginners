# %%
mylist = ("apple", "banana", "cherry")
print(type(mylist))
# Out:
# <class 'tuple'>

# %%
mylist = ["apple", "banana", "cherry"]
print(type(mylist))
# Out:
# <class 'list'>

# %%
mylist = ["apple", "banana", "cherry"]
print(type(mylist))
# Out:
# <class 'list'>
