# %%
students_in_class = 30
average_score = 75.5
teacher_name = "Alex Ehimare"
is_class_active = True
print (students_in_class, average_score, teacher_name, is_class_active)
# Out:
# 30 75.5 Alex Ehimare True

# %%
scores = [85,90,78, 92]
print(scores[0])
scores.append (88)
print(scores)
# Out:
# 85
# [85, 90, 78, 92, 88]

# %%
for name in ["Alice", "Bob", "Charlie"]:
    print("hello", name)
# Out:
# hello Alice
# hello Bob
# hello Charlie

# %%
count = 1
while count <= 3:
    print("attempt", count)
    count += 1
# Out:
# attempt 1
# attempt 2
# attempt 3

# %%
def check_pass(score):
    if score >= 50:
        return "pass"
    else: 
        return "fail"
    print(check_pass(30))

# %%
#Using camelCase for a function name (not typical in python, but possible)
def calculateTotalScore(scores):
    return sum(scores)
print(calculateTotalScore ([80,90,70]))
# Out:
# 240

# %%
##  In Python, the more standard way would be ##
def calculate_total_score(scores):
    return sum(scores)
print(calculate_total_score ([80,90,70]))
# Out:
# 240

# %%
## Snake Case: student_name ##
## variables and fucntions ##
student_name = "Francisca"
def calculate_total_score(scores):
    return sum(scores)
print(student_name)
# Out:
# Francisca

# %%
## CamelCase: StudentRecord ##
## Used for class names ##
class StudentRecord:
# Out:
#   Cell In[44], line 3
#     class StudentRecord:
#                         ^
# _IncompleteInputError: incomplete input
