# %%
age = 12
height = 3.2
name = "Tamilore"
is_student = True
print (age, height, name, is_student)
# Out:
# 12 3.2 Tamilore True

# %%
fruits = ["coconut", "watermelon", "cucumber"]
print(fruits [1])
fruits.append("banana")
print(fruits)
# Out:
# watermelon
# ['coconut', 'watermelon', 'cucumber', 'banana']

# %%
student = { "name": "Abass", "age": 40, "score": 320}
print(student["name"])
student["score"] = 327
print(student)
# Out:
# Abass
# {'name': 'Abass', 'age': 40, 'score': 327}

# %%
score = 327
if score >= 320:
    print ("pass")
else: 
    print ("olodo")
# Out:
# pass

# %%
score = 327
if score <= 325:
    print ("fail")
else:
    print ("pass")
# Out:
# pass

# %%
for fruits in ["cucumber", "coconut", "garri", "agbado"]:
    print (fruits)
# Out:
# cucumber
# coconut
# garri
# agbado

# %%
count = 1
while count <=3:
    print("hello", count)
    count+= 1
# Out:
# hello 1
# hello 2
# hello 3

# %%
def greet (name):
    return f"Hello, {name}"
print (greet ("Abass"))
print (greet ("Tamilore"))
# Out:
# Hello, Abass
# Hello, Tamilore
